# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
import statsmodels.tsa.api as smt
import statsmodels.formula.api as smf
import pylab as py
import warnings
from sklearn import linear_model
from sqlalchemy import create_engine
from statsmodels.stats.outliers_influence import variance_inflation_factor

warnings.filterwarnings(action="ignore")
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'houseprices'

# %%
engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))
houseprices_df = pd.read_sql_query('select * from houseprices',con=engine)

# no need for an open connection, as we're only doing a single query
engine.dispose()

# %% [markdown]
# # Run your house prices model again and assess the goodness of fit of your model using F-test, R-squared, adjusted R-squared, AIC and BIC. Do you think your model is satisfactory? If so, why?

# %%
# x = features
Y = houseprices_df[['saleprice']]
# target variable
X = houseprices_df[['overallqual', 'grlivarea', 'garagecars', 'garagearea', 'totalbsmtsf','firstflrsf']]

X_const = houseprices_df[['overallqual', 'grlivarea', 'garagecars', 'garagearea', 'totalbsmtsf','firstflrsf']]

# We create a LinearRegression model object
# from scikit-learn's linear_model module.
lrm = linear_model.LinearRegression()

# fit method estimates the coefficients using OLS
lrm.fit(X, Y)

# Inspect the results.
print('\nCoefficients: \n', lrm.coef_)
print('\nIntercept: \n', lrm.intercept_)
# Out:
# Coefficients:
#  [[2.39970394e+04 4.31228864e+01 1.45151932e+04 1.56639341e+01
#   2.43907676e+01 1.11859135e+01]]
#
# Intercept:
#  [-102650.90069029]

# %%
X = sm.add_constant(X)

results = sm.OLS(Y, X).fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              saleprice   R-squared:                       0.762
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                     775.0
# Date:                Thu, 06 Feb 2020   Prob (F-statistic):               0.00
# Time:                        18:59:32   Log-Likelihood:                -17496.
# No. Observations:                1460   AIC:                         3.501e+04
# Df Residuals:                    1453   BIC:                         3.504e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const       -1.027e+05   4903.994    -20.932      0.000   -1.12e+05    -9.3e+04
# ...

# %% [markdown]
# F statistic and its associated p-value are 775.0 and 0.00.
# R-squared and adjusted R-squared of the model are 0.762 and 0.761.
# AIC and BIC of the model are 35010 and 35040.

# %% [markdown]
# # In order to improve the goodness of fit of your model, try different model specifications by adding or removing some variables.

# %%
houseprices_df = pd.concat([houseprices_df,pd.get_dummies(houseprices_df.mszoning, prefix="mszoning", drop_first=True)], axis=1)
houseprices_df = pd.concat([houseprices_df,pd.get_dummies(houseprices_df.street, prefix="street", drop_first=True)], axis=1)
dummy_column_names = list(pd.get_dummies(houseprices_df.mszoning, prefix="mszoning", drop_first=True).columns)
dummy_column_names = dummy_column_names + list(pd.get_dummies(house_prices_df.street, prefix="street", drop_first=True).columns)

# %%
# x = features
Y = houseprices_df[['saleprice']]
# target variable
X = houseprices_df[['overallqual', 'grlivarea', 'garagecars', 'garagearea',
                    'totalbsmtsf','firstflrsf','totrmsabvgrd','yearbuilt'] + dummy_column_names]

# We create a LinearRegression model object
# from scikit-learn's linear_model module.
lrm = linear_model.LinearRegression()

# fit method estimates the coefficients using OLS
lrm.fit(X, Y)

# Inspect the results.
print('\nCoefficients: \n', lrm.coef_)
print('\nIntercept: \n', lrm.intercept_)
# Out:
# Coefficients:
#  [[ 2.12799525e+04  5.02630269e+01  1.02913469e+04  1.66995957e+01
#    2.06369726e+01  9.22120904e+00 -9.25849291e+02  2.40701169e+02
#    6.79954804e+03  6.79954804e+03  4.25466432e+03  4.25466432e+03
#    1.02402749e+04  1.02402749e+04  3.30170800e+03  3.30170800e+03
#    9.43717925e+02  9.43717925e+02]]
#
# Intercept:
#  [-571833.64060299]

# %%
X = sm.add_constant(X)

results = sm.OLS(Y, X).fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              saleprice   R-squared:                       0.773
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                     379.4
# Date:                Thu, 06 Feb 2020   Prob (F-statistic):               0.00
# Time:                        20:05:25   Log-Likelihood:                -17461.
# No. Observations:                1460   AIC:                         3.495e+04
# Df Residuals:                    1446   BIC:                         3.502e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# R-squared and adjusted R-squared of the model are 0.773 and 0.771 respectively.
# F statistic and its associated p-value are 379.4 and 0.00. This also indicates that the second model is better than the first one.
# AIC and BIC of the model are 34950 and 35020 . These values are lower than the ones of the first model. The second model is better than the first model because of the R-squared and adjusted R-squared is larger in the second model.
